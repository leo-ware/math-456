# %% [markdown]
# Page 43: problem 3

# %% [markdown]
# **Suppose that $f(z) = x^2 - y^2 - 2y + i(2x - 2xy)$, where $z = x + yi$. Use the expressions $x = {z + \bar{z} \over 2}$ and $y = {z - \bar{z} \over 2i}$ to write $f(z)$ in terms of $z$, and simplify the result.**

# %% [markdown]
# $$
# f(z) = x^2 - y^2 - 2y + i(2x - 2xy)
# $$
#
# $$
# f(z) =
# \left( {z + \bar{z} \over 2} \right)^2
# - \left( {z - \bar{z} \over 2i} \right)^2
# - 2\left( {z - \bar{z} \over 2i} \right)
# + i\left(
#     2\left( {z + \bar{z} \over 2} \right)
#     - 2\left( {z + \bar{z} \over 2} \right)\left( {z - \bar{z} \over 2i} \right)
# \right)
# $$
#
# $$
# f(z) =
# {z^2 + 2z\bar{z} + \bar{z}^2 \over 4}
# - {z^2 - 2z\bar{z} + \bar{z}^2 \over -4}
# - {z - \bar{z} \over i}
# + i\left(
#     (z + \bar{z})
#     - \left( z + \bar{z} \right)\left( {z - \bar{z} \over 2i} \right)
# \right)
# $$
#
# $$
# f(z) =
# {z^2 + 2z\bar{z} + \bar{z}^2 \over 4}
# + {z^2 - 2z\bar{z} + \bar{z}^2 \over 4}
# - i{z - \bar{z} \over -1}
# + i(z + \bar{z})
# - i\left( z + \bar{z} \right)\left( {z - \bar{z} \over 2i}
# \right)
# $$
#
# $$
# f(z) =
# ({1 \over 4}z^2
# + {1 \over 4}2z\bar{z}
# + {1 \over 4}\bar{z}^2)
#
# + ({1 \over 4}z^2
# + {1 \over 4}(- 2z\bar{z})
# + {1 \over 4}\bar{z}^2)
#
# + (iz
# - i\bar{z})
#
# + (iz
# + i\bar{z})
#
# -{1\over 2}\left(
#     z^2 - \bar{z}^2
# \right)
# $$
#
# $$
# f(z) =
# {1 \over 4}z^2
# + {1 \over 4}2z\bar{z}
# + {1 \over 4}\bar{z}^2
#
# + {1 \over 4}z^2
# + {1 \over 4}(- 2z\bar{z})
# + {1 \over 4}\bar{z}^2
#
# + iz
# - i\bar{z}
#
# + iz
# + i\bar{z}
#
# -{1\over 2}z^2
# +{1\over 2}\bar{z}^2
# $$

# %% [markdown]
# $$
# f(z) =
# {1 \over 4}z^2
# + {1 \over 2}z\bar{z}
# + {1 \over 4}\bar{z}^2
#
# + {1 \over 4}z^2
# - {1 \over 2}z\bar{z}
# + {1 \over 4}\bar{z}^2
#
# + iz
# - i\bar{z}
#
# + iz
# + i\bar{z}
#
# -{1\over 2}z^2
# +{1\over 2}\bar{z}^2
# $$
#
# $$
# f(z) =
# {1 \over 4}z^2
# + {1 \over 4}z^2
# -{1\over 2}z^2
#
# + iz
# + iz
#
# + {1 \over 4}\bar{z}^2
# + {1 \over 4}\bar{z}^2
# +{1\over 2}\bar{z}^2
#
# - i\bar{z}
# + i\bar{z}
#
# + {1 \over 2}z\bar{z}
# - {1 \over 2}z\bar{z}
# $$
#
# $$
# f(z) = \bar{z}^2 + 2iz
# $$
