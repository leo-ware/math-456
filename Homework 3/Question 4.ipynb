# %% [markdown]
# **3. From results obtained in Secs. 21 and 23, determine where f′(z) exists and find its value when,**

# %% [markdown]
# **(a) $f(z) = 1/z$**

# %% [markdown]
# $$
# f(z) = {z^{-1}}
# $$
#
# $$
# f(z) = {\bar{z} \over |z|^2}
# $$
#
# So, the domain of $f$ is $z \ne 0$.
#
# Let $z = x + yi$ for real $x$, $y$. Then,
#
# $$
# f(z) = {x - yi \over x^2 + y^2}
# $$
#
# Let $f = u + vi$ where $u$ and $v$ are real-valued functions. Then,
#
# $$
# u = {x \over x^2 + y^2}
# $$
#
# Then,
#
# $$
# u_x = {x'(x^2 + y^2) - x(x^2 + y^2)' \over (x^2 + y^2)^2}
# $$
#
# $$
# u_x = {x^2 + y^2 - x(2x) \over (x^2 + y^2)^2}
# $$
#
# So,
#
# $$
# u_x = {y^2 - x^2 \over (x^2 + y^2)^2}
# $$
#
# This function is defined at $z \ne 0$.
#
# Also,
#
# $$
# u_y = x(-1)(x^2 + y^2)^{-2}(2y)
# $$
#
# So,
#
# $$
# u_y = -{2xy \over (x^2 + y^2)^2}
# $$
#
# This function is defined at $z \ne 0$.
#
# Also,
#
# $$
# v = -{y \over x^2 + y^2}
# $$
#
# Then,
#
# $$
# v_x = -y(-1)(x^2 + y^2)^{-2}(2x)
# $$
#
# So,
#
# $$
# v_x = {2xy \over (x^2 + y^2)^{2}}
# $$
#
# This function is defined at $z \ne 0$.
#
# Also,
#
# $$
# v_y = -{(x^2 + y^2) - y(2y) \over (x^2 + y^2)^2}
# $$
#
# So,
#
# $$
# v_y = {y^2 - x^2 \over (x^2 + y^2)^2}
# $$
#
# This function is defined at $z \ne 0$.

# %% [markdown]
# So, we have that the partials exist and are defined for $z \ne 0$.
#
# Additionally,
#
# $$
# u_x = {y^2 - x^2 \over (x^2 + y^2)^2}
# $$
#
# $$
# u_y = -{2xy \over (x^2 + y^2)^2}
# $$
#
# $$
# v_y = {y^2 - x^2 \over (x^2 + y^2)^2}
# $$
#
# $$
# v_x = {2xy \over (x^2 + y^2)^{2}}
# $$
#
# So,
#
# $$
# u_x = v_y
# $$
#
# And,
#
# $$
# u_x = -v_x
# $$
#
# By Cauchy-Riemann, this suffices to establish that $f'(z)$ for $z \ne 0$.
#
# Then, $f'$ is given by,
#
# $$
# f'(z) = u_x + iv_x
# $$
#
# Then,
#
# $$
# f'(z) = {y^2 - x^2 \over (x^2 + y^2)^2} + i{2xy \over (x^2 + y^2)^{2}}
# $$
#
# So,
#
# $$
# f'(z) = {(y^2 - x^2) + 2xyi \over (x^2 + y^2)^2}
# $$

# %% [markdown]
# **(b) $f(z) = x^2 + y^2i$**

# %% [markdown]
# Let $x$ and $y$ be reals such that $z = x + yi$. Let $u$ and $v$ be real-valued functions such that $f = u + vi$. Then,
#
# $$
# u = x^2
# $$
#
# So,
#
# $$
# u_x = 2x
# $$
#
# $$
# u_y = 0
# $$
#
# Also,
#
# $$
# v = y^2
# $$
#
# So,
#
# $$
# v_y = 2y
# $$
#
# $$
# v_x = 0
# $$
#
# So, the partials exist and are defined everywhere.

# %% [markdown]
# Then, by Cauchy-Riemann, $f'$ is defined where,
#
# $$
# u_x = v_y
# $$
#
# $$
# u_y = -v_x
# $$
#
# Equivalent to,
#
# $$
# 2x = 2y
# $$
#
# $$
# 0 = 0
# $$
#
# So, $f'$ is defined where,
#
# $$
# x = y
# $$
#
# And, its value is given by,
#
# $$
# f'(z) = 2x
# $$

# %% [markdown]
# **(c) $f(z) = z\operatorname{Im} z$**

# %% [markdown]
# Let $x$ and $y$ be reals such that $z = x + yi$. Let $u$ and $v$ be real-valued functions such that $f = u + vi$. Then,
#
# Then,
#
# $$
# f(z) = (x + yi)y
# $$
#
# $$
# f(z) = xy + y^2i
# $$
#
# Then,
#
# $$
# u = xy
# $$
#
# $$
# v = y^2
# $$
#
# Then,
#
# $$
# u_x = y
# $$
#
# $$
# u_y = x
# $$
#
# $$
# v_x = 0
# $$
#
# $$
# v_y = 2y
# $$
#
# So, the partials exist and are defined everywhere.
#
# Then, by Cauchy-Riemann, $f'$ exists where,
#
# $$
# u_x = v_y
# $$
#
# $$
# u_y = -v_x
# $$
#
# Equivalent to,
#
# $$
# y = 2y
# $$
#
# $$
# x = 0
# $$
#
# This system is satisfied only at the origin. So, $f'$ is defined only at the origin, where its value is given by,
#
# $$
# f'(0) = u_x + v_xi
# $$
#
# $$
# f'(0) = (0) + 0i
# $$
#
# $$
# f'(0) = 0
# $$
