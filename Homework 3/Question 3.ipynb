# %% [markdown]
# **1. Use the theorem in Sec. 21 to show that f′(z) does not exist at any point if**

# %% [markdown]
# **(a) $f(z) = \bar{z}$**

# %% [markdown]
# $$
# u(z) = x
# $$
#
# $$
# u_x(z) = 1
# $$
#
# $$
# v(z) = -y
# $$
#
# $$
# v_y(z) = -1
# $$
#
# For $f'$ to exist, it is necessary that $u_x(z) = v_y(z)$. But, this is not the case. So, $f'$ does not exist.

# %% [markdown]
# **(b) $f(z) = z - \bar{z}$**

# %% [markdown]
# $$
# u(z) = 0
# $$
#
# $$
# u_x(z) = 0
# $$
#
# $$
# v(z) = 2y
# $$
#
# $$
# v_y(z) = 2
# $$
#
# For $f'$ to exist, it is necessary that $u_x(z) = v_y(z)$. But, this is not the case. So, $f'$ does not exist.

# %% [markdown]
# **(c)$f(z) = 2x + ixy^2$**

# %% [markdown]
# $$
# u(z) = 2x
# $$
#
# $$
# u_x(z) = 2
# $$
#
# $$
# u_y(z) = 0
# $$
#
# $$
# v(z) = xy^2
# $$
#
# $$
# v_y(z) = 2xy
# $$
#
# $$
# v_x(z) = y^2
# $$
#
# If $f'(z)$ exists, then,
#
# $$
# u_x(z) = v_y(z)
# $$
#
# $$
# u_y(z) = -v_x(z)
# $$
#
# So,
#
# $$
# 2 = 2xy
# $$
#
# $$
# 0 = -y^2
# $$
#
# So,
#
# $$
# 1 = xy
# $$
#
# $$
# 0 = y
# $$
#
# So,
#
# $$
# 1 = x(0)
# $$
#
# $$
# 1 = 0
# $$
#
# Contradiction, $f'$ does not exist.

# %% [markdown]
# **(d) $f(z) = e^xe^{-yi}$**

# %% [markdown]
# By Euler's identity,
#
# $$
# f(z) = e^x(\cos(-y/\pi) + i\sin(-y/\pi))
# $$
#
# Then,
#
# $$
# u(z) = e^x\cos(-y/\pi)
# $$
#
# $$
# v(z) = e^x\sin(-y/\pi)
# $$
#
# Then,
#
# $$
# u_x = e^x\cos(-y/\pi)
# $$
#
# $$
# u_y = {e^x\sin(-y/\pi) \over \pi}
# $$
#
# $$
# v_y = {-e^x\cos(-y/\pi) \over \pi}
# $$
#
# $$
# v_x = e^x\sin(-y/\pi)
# $$
#
# Assume $f'$ exists. Then, by Cauchy-Riemann,
#
# $$
# e^x\cos(-y/\pi) = e^x\cos(-y/\pi)(-1/\pi)
# $$
#
# $$
# \cos(-y/\pi) = \cos(-y/\pi)(-1/\pi)
# $$
#
# Then,
#
# $$
# \cos(-y/\pi) = 0
# $$
#
# Then, for some integer $n^*$,
#
# $$
# -y/\pi = (n + {1\over 2})\pi
# $$
#
# Then, for some integer $n$,
#
# $$
# y = (n + {1\over 2})\pi^2
# $$
#
# By Cauchy-Riemann,
#
# $$
# {e^x\sin(-y/\pi) \over \pi} = -e^x\sin(-y/\pi)
# $$
#
# $$
# {\sin(-y/\pi) \over \pi} = -\sin(-y/\pi)
# $$
#
# Then,
#
# $$
# \sin(-y/\pi) = 0
# $$
#
# Then, for some integer $m^*$,
#
# $$
# -y/\pi = m^*\pi
# $$
#
# Then, for some integer $m$,
#
# $$
# y = m\pi^2
# $$
#
# Then, there exist integers $m$, $n$ such that,
#
# $$
# m\pi^2 = (n + {1\over 2})\pi^2
# $$
#
# $$
# m = n + {1\over 2}
# $$
#
# $$
# m - n = {1 \over 2}
# $$
#
# The integers are closed under subtraction, so $m - n$ is an integer. But, no integer is equal to $1/2$.
#
# Contradiction, $f'$ does not exist.
