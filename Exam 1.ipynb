# %% [markdown]
# My test was pretty messy, so I just decided to type it up.

# %% [markdown]
# # Question 1
#
# **Find differentiable functions $w = f(z)$ whose imaginary part is:**
#
# **(a)** $v(x, y) = (x + 2)y$

# %% [markdown]
# Then,
#
# $$
# v_y = x + 2
# $$
#
# $$
# v_x = y
# $$

# %% [markdown]
# We have that $f$ is differentiable. So, by Cauchy-Riemann,
#
# $$
# v_y = u_x
# $$
#
# Then,
#
# $$
# u_x = x + 2
# $$
#
# $$
# u = \int x + 2 dx
# $$
#
# $$
# u = {1 \over 2}x^2 + 2x + C_1(y)
# $$

# %% [markdown]
# $$
# u_y = {d \over dy} \left( {1 \over 2}x^2 + 2x + C_1(y) \right)
# $$
#
# $$
# u_y = C_1'(y)
# $$
#
# By Cauchy Riemann,
#
# $$
# v_x = -u_y
# $$
#
# So,
#
# $$
# C_1'(y) = -y
# $$
#
# $$
# C_1(y) = \int -y dy
# $$
#
# $$
# C_1(y) = -{1 \over 2}y^2 + C_2
# $$
#
# So,
#
# $$
# u = {1 \over 2}x^2 + 2x + -{1 \over 2}y^2 + C_2
# $$
#
# We have that $u$ is real valued. So, $C_2 \in \R$.

# %% [markdown]
# The partials are,
#
# $$
# v_y = x + 2
# $$
#
# $$
# v_x = y
# $$
#
# $$
# u_x = x + 2
# $$
#
# $$
# u_y = -y
# $$
#
# These are polynomials, so they are continuous for all $x$, $y$. So, derivative of $f$ is defined for all $x$, $y$, and it is given by,
#
# $$
# f' = u_x + iv_x = (x + 2) + yi
# $$

# %% [markdown]
# So, for any $C_2 \in \mathbb{R}$, differentiable functions with the specified imaginary part are given by,
#
# $$
# f = \left( {1 \over 2}x^2 + 2x + -{1 \over 2}y^2 + C_2 \right) + i((x + 2)y)
# $$

# %% [markdown]
# **(b)**
#
# $$
# v = {x \over x^2 + y^2}
# $$

# %% [markdown]
# Then,
#
# $$
# v_y = {d \over dy}x(x^2 + y^2)^{-1}
# $$
#
# $$
# v_y = -x(x^2 + y^2)^{-2}2y
# $$
#
# $$
# v_y = -{2xy \over (x^2 + y^2)^2}
# $$
#
# Also,
#
# $$
# v_x = {d \over dx}x(x^2 + y^2)^{-1}
# $$
#
# $$
# v_x = (x^2 + y^2)^{-1} + x{d \over dx}(x^2 + y^2)^{-1}
# $$
#
# $$
# v_x = (x^2 + y^2)^{-1} + x(-1)(x^2 + y^2)^{-2}2x
# $$
#
# $$
# v_x = {1 \over x^2 + y^2} -{2x^2 \over (x^2 + y^2)^{2}}
# $$

# %% [markdown]
# We have that $f$ is differentiable. Then, by Cauchy-Riemann,
#
# $$
# u_x = v_y
# $$
#
# Then,
#
# $$
# u_x = -{2xy \over (x^2 + y^2)^2}
# $$
#
# Then,
#
# $$
# u = \int -{2xy \over (x^2 + y^2)^2} dx
# $$

# %% [markdown]
# Let,
#
# $$
# w = x^2 + y^2
# $$
#
# $$
# {dw \over dx} = 2x
# $$
#
# Then,
#
# $$
# u = \int -{y \over w^2}dw
# $$
#
# $$
# u = \int -yw^{-2}dw
# $$
#
# $$
# u = yw^{-1} + C_1(y)
# $$
#
# $$
# u = {y \over x^2 + y^2} + C_1(y)
# $$
#
# And, $C_1(y)$ is real-valued.

# %% [markdown]
# Then,
#
# $$
# u_y = {d\over dy}\left( {y \over x^2 + y^2} + C_1(y) \right)
# $$
#
# $$
# u_y = {1 \over x^2 + y^2} + y{d\over dy}\left( (x^2 + y^2)^{-1} \right) + C_1'(y)
# $$
#
# $$
# u_y = {1 \over x^2 + y^2} + y(-1) \left( (x^2 + y^2)^{-2}2y \right) + C_1'(y)
# $$
#
# $$
# u_y = {1 \over x^2 + y^2} - {2y^2 \over (x^2 + y^2)^{2}} + C_1'(y)
# $$

# %% [markdown]
# By Cauchy-Riemann,
#
# $$
# u_y = -v_x
# $$
#
# $$
# {1 \over x^2 + y^2} -{2x^2 \over (x^2 + y^2)^{2}} = -\left({1 \over x^2 + y^2} - {2y^2 \over (x^2 + y^2)^{2}} + C_1'(y) \right)
# $$
#
# $$
# {1 \over x^2 + y^2} -{2x^2 \over (x^2 + y^2)^{2}} = -{1 \over x^2 + y^2} + {2y^2 \over (x^2 + y^2)^{2}} - C_1'(y)
# $$
#
# $$
# C_1'(y) =
# {2y^2 \over (x^2 + y^2)^{2}}
# -{2 \over x^2 + y^2}
# + {2x^2 \over (x^2 + y^2)^{2}}
# $$

# %% [markdown]
# $$
# C_1(y) = \int
# {2y^2 \over (x^2 + y^2)^{2}}
# -{2 \over x^2 + y^2}
# + {2x^2 \over (x^2 + y^2)^{2}}
# dy
# $$
#
# $$
# C_1(y) = \int
# {2y^2 \over (x^2 + y^2)^{2}}
# -{1 \over x^2 + y^2}
# + {2x^2 \over (x^2 + y^2)^{2}}
# -{1 \over x^2 + y^2}
# dy
# $$
#
# $$
# C_1(y) = \int
# {2y^2 \over (x^2 + y^2)^{2}}
# -{1 \over x^2 + y^2}dy
# + \int
# {2x^2 \over (x^2 + y^2)^{2}}
# -{1 \over x^2 + y^2}
# dy
# $$
#
# $$
# C_1(y) =
# -\int
# {1 \over x^2 + y^2}
# -{2y^2 \over (x^2 + y^2)^{2}}
# dy
# - \int
# {1 \over x^2 + y^2}
# -{2x^2 \over (x^2 + y^2)^{2}}
# dy
# $$
#
# We just did this integral in reverse,
#
# $$
# C_1(y) =
# - {y \over x^2 + y^2}
# - {x \over x^2 + y^2}
# + C_2
# $$

# %% [markdown]
# We have that $C_1$ is a function of $x$ and $y$. Under the assumption that $f$ is differentiable, we showed that it is a function of $y$. So, there are no differentiable functions with this complex part.

# %% [markdown]
# # Question 2

# %% [markdown]
# **Sketch or graph the given region and its image under the following mapping.**
#
# **(a)** $1 \lt |z| \lt 3$, $-\pi /6 \lt \operatorname{Arg} z \lt \pi/6$, $w = z^3$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Translating $z$ into polar,
#
# $$
# z = \psi \exp(i \theta)
# $$
#
# And, we have the constraints that,
#
# $$
# \psi \in (1, 3)
# $$
#
# $$
# \theta \in (-\pi /6, \pi/6)
# $$
#
# We have that,
#
# $$
# w = z^3
# $$
#
# So,
#
# $$
# w = (\psi \exp(i \theta))^3
# $$
#
# $$
# w = \psi^3 \exp(i 3\theta)
# $$
#
# From the above bounds,
#
# $$
# \psi^3 \in (1, 9)
# $$
#
# $$
# 3\theta \in (-\pi/2, \pi /2)
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **(b)** $-1 \lt \operatorname{Im}z \lt 1$, $w = -iz$

# %% [markdown]
# There's no constraint on the real part of $z$. The imaginary part is on the open set $(-1, 1)$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can represent $z$ in rectangular form as,
#
# $$
# z = x + yi
# $$
#
# With the constraint that,
#
# $$
# y \in (-1, 1)
# $$
#
# Then,
#
# $$
# w = -iz
# $$
#
# $$
# w = -i(x + yi)
# $$
#
# $$
# w = y - ix
# $$
#
# We dont have a constraint on $x$, so the imaginary part can be anything. The real part is on the open set $(-1, 1)$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **(c)** $x \le -1$, $w = {1\over z}$

# %% [markdown]
# The real part is less than or equal to -1. The imaginary part can be anything.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can represent $z$ as,
#
# $$
# z = x + yi
# $$
#
# The constraint is now that C is a nonnegative real number.
#
# We have that,
#
# $$
# w = {1 \over z}
# $$
#
# So,
#
# $$
# z = {1 \over w}
# $$
#
# If $w = u + vi$, then,
#
# $$
# {1 \over w} = {u - vi \over u^2 + v^2}
# $$
#
# So,
#
# $$
# x = {u \over u^2 + y^2}
# $$
#
# $$
# {u \over u^2 + y^2} \le -1
# $$
#
# $$
# u \le -(u^2 + y^2)
# $$
#
# $$
# u^2 + u + y^2 \le 0
# $$
#
# $$
# u^2 + u + {1 \over 4} - {1 \over 4} + y^2 \le 0
# $$
#
# $$
# \left( u + {1 \over 2} \right)^2 + y^2 \le {1\over 4}
# $$
#
# $$
# \left( u + {1 \over 2} \right)^2 + y^2 \le \left({1\over 2}\right)^2
# $$
#
# So, this is the circle centered at $(-1/2, 0)$ with radius $1/2$. This includes the boundary; it's a closed set.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 3
#
# **Where is the function $f(z) = z\operatorname{Im}(z^2) - i(\bar{z} + 1)^2$ differentiable?**

# %% [markdown]
# $$
# f(z) = z\operatorname{Im}(z^2) - i(\bar{z} + 1)^2
# $$
#
# So,
#
# $$
# f(z) = (x + yi)2xy - i\bar{z}^2 -2i\bar{z} -i
# $$
#
# $$
# f(z) = (x + yi)2xy - i((x^2 - y^2) - 2xyi) - 2i(x - yi) -i
# $$
#
# $$
# f(z) = 2x^2y + 2xy^2i - ix^2 + y^2i - 2xy - 2ix -2y - i
# $$
#
# $$
# f(z) = (2x^2y - 2xy -2y) + i(2xy^2 - x^2 + y^2 - 2x - 1)
# $$

# %% [markdown]
# So,
#
# $$
# u = 2x^2y - 2xy - 2y
# $$
#
# $$
# v = 2xy^2 - x^2 + y^2 - 2x - 1
# $$
#
# So,
#
# $$
# u_x = 4xy - 2y
# $$
#
# $$
# u_y = 2x^2 - 2x - 2
# $$
#
# And,
#
# $$
# v_x = 2y^2 - 2x - 2
# $$
#
# $$
# v_y = 4xy + 2y
# $$

# %% [markdown]
# The partials are continuous, so where the Cauchy-Riemann equations hold, the derivative will be defined. Checking the first condition, we get,
#
# $$
# u_x = v_y
# $$
#
# $$
# 4xy - 2y = 4xy + 2y
# $$
#
# $$
# y = -y
# $$
#
# $$
# y = 0
# $$
#
# Checking the second condition, we get,
#
# $$
# u_y = -v_x
# $$
#
# $$
# 2x^2 - 2x - 2 = -(2y^2 - 2x - 2)
# $$
#
# $$
# 2x^2 - 2x - 2 = -2y^2 + 2x + 2
# $$
#
# We already know the derivative is only defined when $y = 0$, so we can constrain the search to this region.
#
# $$
# 2x^2 - 2x - 2 = 2x + 2
# $$
#
# $$
# x^2 - 2x - 2 = 0
# $$
#
# Applying the quadratic formula, we get,
#
# $$
# x = {-(-2) \pm \sqrt{(-2)^2 - 4(1)(-2)} \over 2}
# $$
#
# $$
# x = {2 \pm \sqrt{4 + 8} \over 2}
# $$
#
# $$
# x = {2 \pm 2\sqrt{3} \over 2}
# $$
#
# $$
# x = 1 \pm \sqrt{3}
# $$
#
# So, the derivative is defined at the real numbers $1 + \sqrt{3}$ and $1 - \sqrt{3}$.

# %% [markdown]
# # Question 4
#
# **Consider the function $f : \mathbb{C} \to \mathbb{C}$ given by,**
#
# $$
# f(z) = \begin{cases}
# {(y - 1)^3 - ix^3 \over x^2 + (y - 1)^2} & \text{if } z \ne i \\
# 0 & \text{if } z = i
# \end{cases}
# $$
#
# **Prove that the Cauchy-Riemann equations hold at $z = i$. Is $f$ differentiable at $z = i$? If so, find the derivative.**

# %% [markdown]
# Let,
#
# $$
# u(x, y) = \begin{cases}
# {(y - 1)^3 \over x^2 + (y - 1)^2} & \text{if } z \ne i \\
# 0 & \text{if } z = i
# \end{cases}
# $$
#
# $$
# v(x, y) = \begin{cases}
# {-x^3 \over x^2 + (y - 1)^2} & \text{if } z \ne i \\
# 0 & \text{if } z = i
# \end{cases}
# $$
#
# Then, $u$ and $v$ are real-valued functions such that,
#
# $$
# f = u + vi
# $$

# %% [markdown]
# We are interested in the partial derivatives at $z = i$.
#
# $$
# u_x(0, 1) = \lim_{\Delta x \to 0} {u(0 + \Delta x, 1) - u(0, 1) \over x}
# $$
#
# $$
# u_x(0, 1) = \lim_{x \to 0} {
#     {((1) - 1)^3 \over (\Delta x)^2 + ((1) - 1)^2} - 0
# \over \Delta x}
# $$
#
# $$
# u_x(0, 1) = 0
# $$
#
# $$
# u_y(0, 1) = \lim_{\Delta y \to 0} {u(0, \Delta y + 1) - u(0, 1) \over \Delta y}
# $$
#
# $$
# u_y(0, 1) = \lim_{\Delta y \to 0} {
#     {((\Delta y + 1) - 1)^3 \over (0)^2 + ((\Delta y + 1) - 1)^2}
#     - 0
# \over \Delta y}
# $$
#
# $$
# u_y(0, 1) = \lim_{\Delta y \to 0} {
#     \left( {\Delta y^3 \over \Delta y^2} \right)
# \over \Delta y}
# $$
#
# $$
# u_y(0, 1) = \lim_{\Delta y \to 0} {\Delta y^3 \over \Delta y^3}
# $$
#
# $$
# u_y(0, 1) = 1
# $$

# %% [markdown]
# $$
# v_x(0, 1) = \lim_{\Delta x \to 0} {
#     v(\Delta x + 0, 1) + v(0, 1)
# \over \Delta x}
# $$
#
# $$
# v_x(0, 1) = \lim_{\Delta x \to 0} {
#     {-(\Delta x + 0)^3 \over (\Delta x + 0)^2 + ((1) - 1)^2} + 0
# \over \Delta x}
# $$
#
# $$
# v_x(0, 1) = \lim_{\Delta x \to 0} {
#     {-\Delta x^3 \over \Delta x^2}
# \over \Delta x}
# $$
#
# $$
# v_x(0, 1) = -1
# $$
#
# $$
# v_x(0, 1) = \lim_{\Delta y \to 0} {
#     {-(0)^3 \over (0)^2 + ((\Delta y + 1) - 1)^2} + 0
# \over \Delta y}
# $$
#
# $$
# v_x(0, 1) = 0
# $$

# %% [markdown]
# So,
#
# $$
# u_x = v_y = 0
# $$
#
# $$
# u_y = -v_x = 1
# $$
#
# The Cauchy-Riemann equations are satisfied at $z = i$.

# %% [markdown]
# The derivative of $f$ at $z = i$ is given by,
#
# $$
# f'(0, 1) = \lim_{\Delta x, \Delta y \to 0} {f(\Delta x + 0, \Delta y + 1) - f(0, 1) \over \Delta x + i\Delta y}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta x, \Delta y \to 0} {
# {((\Delta y + 1) - 1)^3 - i\Delta x^3 \over \Delta x^2 + ((\Delta y + 1) - 1)^2}
# - 0
# \over \Delta x + i\Delta y}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta x, \Delta y \to 0} {
# \left( {\Delta y^3 - i\Delta x^3 \over \Delta x^2 + \Delta y^2} \right)
# \over \Delta x + i\Delta y}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta x, \Delta y \to 0}
# {\Delta y^3 - i\Delta x^3 \over (\Delta x^2 + \Delta y^2)(\Delta x + i\Delta y)}
# $$

# %% [markdown]
# Consider the approach $\Delta x \to 0$ while $\Delta y = 0$
#
# $$
# f'(0, 1) = \lim_{\Delta x\to 0}
# {(0)^3 - i\Delta x^3 \over (\Delta x^2 + (0)^2)(\Delta x + i(0))}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta x\to 0}
# {- i\Delta x^3 \over \Delta x^3}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta x\to 0}
# - i
# $$
#
# $$
# f'(0, 1) = -i
# $$

# %% [markdown]
# Consider the approach $\Delta y \to 0$ while $\Delta x = 0$
#
# $$
# f'(0, 1) = \lim_{\Delta y \to 0}
# {\Delta y^3 - i(0)^3 \over ((0)^2 + \Delta y^2)((0) + i\Delta y)}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta y \to 0}
# {\Delta y^3 \over i\Delta y^3}
# $$
#
# $$
# f'(0, 1) = \lim_{\Delta y \to 0}
# {1 \over i}
# $$
#
# $$
# f'(0, 1) = {1 \over i}
# $$

# %% [markdown]
# But, limits are unique. So, $f'(0, 1)$ does not exist.
