# %% [markdown]
# Page 124: problem 2

# %% [markdown]
# **2. Let C denote the right-hand half of the circle |z| = 2, in the counterclockwise direction, and note that two parametric representations for C are**
#
# $$
# z = z(\theta) = 2e^{i\theta} \quad \left(-{\pi\over 2} \le \theta \le {\pi \over 2} \right)
# $$
#
# $$
# z = Z(\theta) = \sqrt{4 - y^2} + iy \quad (-2 \le y \le 2)
# $$
#
# **Verify that $Z(y) = z[\phi(y)]$ where,**
#
# $$
# \phi(y) = \arctan {y \over \sqrt{4 - y^2}} \quad \left( -{\pi \over 2} \le \arctan(t) \le {\pi \over 2} \right)
# $$
#
# **Also, show that the function $\phi$ has a positive derivative, as required in the conditions following equation (9), section 43.**

# %% [markdown]
# The complex $\arctan$ is given by,
#
# $$
# \arctan(z) = {1 \over 2i}[\log(1 + iz) - \log(1 - iz)]
# $$
#
# $$
# \arctan(z) = {1 \over 2i}[\log(1 + iz) - \log(1 - iz)]
# $$
