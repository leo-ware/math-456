# %% [markdown]
# Page 133: problem 10

# %% [markdown]
# **10. With the aid of the result in Exercise 3, Sec. 42, evaluate the integral**
#
# $$
# \int_C z^m\bar{z}^n dz
# $$
#
# **where $m$ and $n$ are integers and $C$ is the unit circle $|z| = 1$, taken counterclockwise.**

# %% [markdown]
# **Result from exercise 42.3**
#
# **Suppose $m$ and $n$ are integers. Then,**
#
# $$
# \int_0^{2\pi} e^{im\theta}e^{-in\theta} d\theta =
# \begin{cases}
# 0 & \text{when } m \ne n \\
# 2\pi & \text{when } m = n
# \end{cases}
# $$

# %% [markdown]
# We can parametrize $C$ as,
#
# $$
# C: z = \exp(i\theta) \quad \theta: 0 \to 2\pi
# $$
#
# Then,
#
# $$
# \bar{z} = \exp(-i\theta)
# $$
#
# Also,
#
# $$
# dz = i\exp(i\theta)d\theta
# $$
#
# Also,
#
# $$
# f(z(\theta)) = \exp(i\theta)^m\exp(-i\theta)^n
# $$
#
# Then,
#
# $$
# \int_C f(z(\theta)) = \int_0^{2\pi} \exp(i\theta m)\exp(-i\theta n) i\exp(i\theta)d\theta
# $$
#
# $$
# \int_C f(z(\theta)) = i\int_0^{2\pi} \exp(i\theta (m + 1))\exp(-i\theta n)d\theta
# $$
#
# We can apply the result of 42.3 to get,
#
# $$
# \int_C f(z(\theta)) =
# \begin{cases}
# 0 & \text{when } m + 1 \ne n \\
# 2\pi i & \text{when } m + 1 = n
# \end{cases}
# $$
